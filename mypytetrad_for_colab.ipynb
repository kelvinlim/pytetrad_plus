# %%
# !apt-get update -qq && apt-get install -y openjdk-21-jdk-headless -qq > /dev/null
# !wget -q https://download.oracle.com/java/21/archive/jdk-21.0.6_linux-x64_bin.tar.gz -O jdk-21.0.6_linux-x64_bin.tar.gz
# !ls -l jdk-21.0.6_linux-x64_bin.tar.gz
# !tar xf jdk-21.0.6_linux-x64_bin.tar.gz
# !export JAVA_HOME=/content/jdk-21.0.6
# !$JAVA_HOME/bin/java -version
# !echo $JAVA_HOME
# !export PATH=$JAVA_HOME/bin:$PATH
# !echo $PATH
# !java -version
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# -rw------- 1 root root 197405999 Dec  3 11:08 jdk-21.0.6_linux-x64_bin.tar.gz
# openjdk version "21.0.6" 2025-01-21
# OpenJDK Runtime Environment (build 21.0.6+7-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 21.0.6+7-Ubuntu-122.04.1, mixed mode, sharing)
#
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin
# openjdk version "21.0.6" 2025-01-21
# OpenJDK Runtime Environment (build 21.0.6+7-Ubuntu-122.04.1)
# OpenJDK 64-Bit Server VM (build 21.0.6+7-Ubuntu-122.04.1, mixed mode, sharing)

# %%
# Jpype1 for interacting with tetrad with python
# !pip install JPype1
# pytetrad package
# !pip install git+https://github.com/cmu-phil/py-tetrad
# extras to add to pytetrad to support use in jupyter notebooks and processing
# !pip install pytetrad_plus
# Out:
# Requirement already satisfied: JPype1 in ./.venv/lib/python3.13/site-packages (1.5.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from JPype1) (24.2)
# Collecting git+https://github.com/cmu-phil/py-tetrad
#   Cloning https://github.com/cmu-phil/py-tetrad to /tmp/pip-req-build-r8glikhv
#   Running command git clone --filter=blob:none --quiet https://github.com/cmu-phil/py-tetrad /tmp/pip-req-build-r8glikhv
#   Resolved https://github.com/cmu-phil/py-tetrad to commit 91ed58345805d6945f5a7b9e38c2328c05896d44
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in ./.venv/lib/python3.13/site-packages (from py-tetrad==0.1.2) (2.2.4)
# Requirement already satisfied: pandas in ./.venv/lib/python3.13/site-packages (from py-tetrad==0.1.2) (2.2.3)
# Requirement already satisfied: JPype1 in ./.venv/lib/python3.13/site-packages (from py-tetrad==0.1.2) (1.5.2)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from JPype1->py-tetrad==0.1.2) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas->py-tetrad==0.1.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.13/site-packages (from pandas->py-tetrad==0.1.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.13/site-packages (from pandas->py-tetrad==0.1.2) (2025.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->py-tetrad==0.1.2) (1.17.0)

# %%
# !pip install dgraph_flex
# Out:
# Requirement already satisfied: dgraph_flex in ./.venv/lib/python3.13/site-packages (0.1.4.1)
# Requirement already satisfied: graphviz in ./.venv/lib/python3.13/site-packages (from dgraph_flex) (0.20.3)
# Requirement already satisfied: pyaml in ./.venv/lib/python3.13/site-packages (from dgraph_flex) (25.1.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.13/site-packages (from dgraph_flex) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (2.2.4)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (24.2)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.13/site-packages (from matplotlib->dgraph_flex) (2.9.0.post0)
# Requirement already satisfied: PyYAML in ./.venv/lib/python3.13/site-packages (from pyaml->dgraph_flex) (6.0.2)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib->dgraph_flex) (1.17.0)

# %%
from dgraph_flex import DgraphFlex

obj = DgraphFlex()
# add edges to graph object
obj.add_edge('A', '-->', 'B', color='green', strength=-0.5, pvalue=0.01)
obj.add_edge('B', '-->', 'C', color='red', strength=-.5, pvalue=0.001)
obj.add_edge('C', '-->', 'E', color='green', strength=0.5, pvalue=0.005)
obj.add_edge('D', 'o-o', 'B')
# load into graphviz object and render to window
obj.show_graph()

# %% [markdown]
# Run an analysis on my own data. I need to be able to mount a google drive.

# %%
from google.colab import drive
from pathlib import Path
import os

drive.mount('/content/drive')


path = '/content/drive/MyDrive/Coursework2025_Spring/Spring2025_HINF5660_CDA/Project/ColabDemo'
os.listdir(path)

# !rm -rf /content/ColabDemo

# create symbolic link
# !ln -s /content/drive/MyDrive/Coursework2025_Spring/Spring2025_HINF5660_CDA/Project/ColabDemo /content/ColabDemo

# !ls -l /content/ColabDemo

# list the ColabDemo folder
print(os.listdir('/content'))
os.listdir('/content/ColabDemo')

# move to the /content/ColabDemo folder
# %cd /content/ColabDemo

# !ls data_boston
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# lrwxrwxrwx 1 root root 86 Apr 22 02:29 /content/ColabDemo -> /content/drive/MyDrive/Coursework2025_Spring/Spring2025_HINF5660_CDA/Project/ColabDemo
# ['.config', 'drive', 'py-tetrad', 'jdk-21.0.6_linux-x64_bin.tar.gz', 'ColabDemo', 'jdk-21.0.6', 'sample_data']
# /content/drive/.shortcut-targets-by-id/1R6bT3mzo8YMLScsxZOLpWPyw0RXLcM_Z/Coursework2025_Spring/Spring2025_HINF5660_CDA/Project/ColabDemo
#  boston_data.csv
#  boston_data_raw.csv
#  boston_permuted_results_20250419_perm-1000.json
#  boston_permuted_results.json
#  boston_prior.txt
# 'dist_Boston COVID Data.png'
#  fpr_boston_permuted_results_20250416_1814.png
#  fpr_boston_permuted_results_20250417_1632.csv
#  fpr_boston_permuted_results_20250417_1652.csv
#  fpr_boston_permuted_results_20250417_1652.png
#  fpr_boston_permuted_results_20250417_1737.csv
#  fpr_boston_permuted_results_20250417_1737.png
#  fpr_boston_permuted_results_20250419_1618.csv
#  fpr_boston_permuted_results_20250419_1618.png
#  fpr_boston_permuted_results_20250419_1642.csv
#  fpr_boston_permuted_results_20250419_1642.png
#  fpr_boston_permuted_results_20250419_1651.csv
#  fpr_boston_permuted_results_20250419_1651.png

# %%
# get line counts
# !wc  data_boston/boston_data_raw.csv
# !wc  data_boston/boston_data.csv
# Out:
#   642   642 30641 data_boston/boston_data_raw.csv
#    622    622 166889 data_boston/boston_data.csv

# %%
# read data

from pytetrad_plus import MyTetradSearch
import pprint

ts = MyTetradSearch()

# read data
df_raw = ts.read_csv('data_boston/boston_data_raw.csv')
df = ts.read_csv('data_boston/boston_data.csv')

df_raw
# Out:
#      alcohol_bev    TIB       TST  PANAS_PA  PANAS_NA  worry_scale  PHQ9
# 0            1.0   9.00  7.333333      44.0      13.0          8.0   0.0
# 1            0.0  10.25  8.750000      40.0      12.0         14.0   0.0
# 2            1.0   8.50  7.166667      39.0      12.0         15.0   0.0
# 3            1.0   8.75  8.083333      39.0      12.0         12.0   0.0
# 4            1.0   8.25  6.666667      38.0      13.0         15.0   0.0
# ..           ...    ...       ...       ...       ...          ...   ...
# 636          4.0   8.75  7.916667      29.0      12.0         17.0   3.0
# 637          4.0   8.50  7.666667      31.0      12.0         17.0   4.0
# 638          3.0   8.50  7.583333      33.0      13.0         17.0   3.0
# 639          3.0   9.00  8.166667      31.0      12.0         19.0   2.0
# 640          4.0   8.25  7.416667      31.0      13.0         17.0   1.0
#
# [641 rows x 7 columns]

# %%
    # add the lag columns
    df_lag = ts.add_lag_columns(df, lag_stub='_lag')
    # standardize the data
    df_lag_std = ts.standardize_df_cols(df_lag)

    print(f"DataFrame loaded and lag columns added, columns standardized. Number of rows: {len(df_lag)}")
    df_lag
# Out:
# DataFrame loaded and lag columns added, columns standardized. Number of rows: 640
#      alcohol_bev    TIB       TST  PANAS_PA  PANAS_NA  worry_scale  PHQ9  \
# 0            0.0  10.25  8.750000      40.0      12.0         14.0   0.0
# 1            1.0   8.50  7.166667      39.0      12.0         15.0   0.0
# 2            1.0   8.75  8.083333      39.0      12.0         12.0   0.0
# 3            1.0   8.25  6.666667      38.0      13.0         15.0   0.0
# 4            0.0   8.25  7.416667      37.0      12.0         16.0   0.0
# ..           ...    ...       ...       ...       ...          ...   ...
# 635          4.0   8.75  7.916667      29.0      12.0         17.0   3.0
# 636          4.0   8.50  7.666667      31.0      12.0         17.0   4.0
# 637          3.0   8.50  7.583333      33.0      13.0         17.0   3.0
# 638          3.0   9.00  8.166667      31.0      12.0         19.0   2.0
# 639          4.0   8.25  7.416667      31.0      13.0         17.0   1.0
#
#      alcohol_bev_lag  TIB_lag   TST_lag  PANAS_PA_lag  PANAS_NA_lag  \
# 0                1.0     9.00  7.333333          44.0          13.0
# 1                0.0    10.25  8.750000          40.0          12.0
# 2                1.0     8.50  7.166667          39.0          12.0
# 3                1.0     8.75  8.083333          39.0          12.0
# 4                1.0     8.25  6.666667          38.0          13.0
# ..               ...      ...       ...           ...           ...
# 635              6.0     7.00  6.166667          31.0          15.0
# 636              4.0     8.75  7.916667          29.0          12.0
# 637              4.0     8.50  7.666667          31.0          12.0
# 638              3.0     8.50  7.583333          33.0          13.0
# 639              3.0     9.00  8.166667          31.0          12.0
#
#      worry_scale_lag  PHQ9_lag
# 0                8.0       0.0
# 1               14.0       0.0
# 2               15.0       0.0
# 3               12.0       0.0
# 4               15.0       0.0
# ..               ...       ...
# 635             18.0       3.0
# 636             17.0       3.0
# 637             17.0       4.0
# 638             17.0       3.0
# 639             19.0       2.0
#
# [640 rows x 14 columns]

# %%
df1 = df.copy()
df2 = df_lag_std.copy()

print(f"Dataframes are equal: {df1.equals(df2)}")

diff_mask = df.ne(df2)

# Apply styling
def highlight_diff(data, diff_mask):
    # Create a dataframe of the same shape with empty strings
    # This is necessary for applying styles based on another dataframe (the mask)
    empty_df = pd.DataFrame('', index=data.index, columns=data.columns)
    # Apply a background color to cells where diff_mask is True
    return empty_df.mask(diff_mask, 'background-color: yellow')

# Apply the styling to one of the dataframes (e.g., df1) based on the diff_mask
# You can then display both styled dataframes side-by-side for comparison
df1_styled = df1.style.apply(highlight_diff, diff_mask=diff_mask, axis=None)
df2_styled = df2.style.apply(highlight_diff, diff_mask=diff_mask, axis=None)

print("Dataframe 1 with differences highlighted:")
display(df1_styled) # Use display() in environments that support it

print("\nDataframe 2 with differences highlighted:")
display(df2_styled) # Use display() in environments that support it
# Out:
# Dataframes are equal: False
# Dataframe 1 with differences highlighted:
# <style type="text/css">
fded_row12_col4, #T_9fded_row12_col5, #T_9fded_row12_col6, #T_9fded_row12_col7, #T_9fded_row12_col8, #T_9fded_row12_col9, #T_9fded_row12_col10, #T_9fded_row12_col11, #T_9fded_row12_col12, #T_9fded_row12_col13, #T_9fded_row13_col0, #T_9fded_row13_col1, #T_9fded_row13_col2, #T_9fded_row13_col3, #T_9fded_row13_col4, #T_9fded_row13_col5, #T_9fded_row13_col6, #T_9fded_row13_col7, #T_9fded_row13_col8, #T_9fded_row13_col9, #T_9fded_row13_col10, #T_9fded_row13_col11, #T_9fded_row ...

# %%
print(len(df1))
print(len(df2))
# Out:
# 621
# 640

# %%
# load prior
prior_lines = ts.read_prior_file('data_boston/boston_prior.txt')
# extract knowledge
knowledge = ts.extract_knowledge(prior_lines)
pprint.pprint(knowledge)

ts.load_knowledge(knowledge)

searchResult = ts.run_model_search(df, model='gfci',
                                                    knowledge=knowledge,
                                                    score={'sem_bic': {'penalty_discount': 1.0}},
                                                    test={'fisher_z': {'alpha': .05}})

edges = list(searchResult['setEdges'])
pprint.pprint(edges)
# Out:
# {'addtemporal': {0: ['alcohol_bev_lag',
#                      'TIB_lag',
#                      'TST_lag',
#                      'PANAS_PA_lag',
#                      'PANAS_NA_lag',
#                      'worry_scale_lag',
#                      'PHQ9_lag'],
#                  1: ['alcohol_bev',
#                      'TIB',
#                      'TST',
#                      'PANAS_PA',
#                      'PANAS_NA',
#                      'worry_scale',
#                      'PHQ9']}}
# ['PHQ9_lag o-> PHQ9',
#  'TIB_lag o-> TST_lag',
#  'worry_scale_lag o-> PANAS_PA',
#  'PANAS_PA_lag o-> PANAS_PA',
#  'worry_scale_lag o-> worry_scale',
#  'TIB o-> TST',
#  'PHQ9_lag o-o PANAS_PA_lag',
#  'PHQ9_lag o-o PANAS_NA_lag',
#  'PHQ9 --> PANAS_PA',
#  'worry_scale --> TST',
#  'PANAS_NA_lag o-> TST_lag',
#  'PANAS_NA_lag o-> PANAS_NA',
#  'PANAS_NA_lag o-> PHQ9',
#  'PANAS_NA o-> PHQ9']

# %%
from dgraph_flex import DgraphFlex
# create graph output
obj = DgraphFlex()
# add edges to graph object
for edge in edges:
  source,edge_type, target = edge.split(' ')
  obj.add_edge(source,edge_type, target, color='purple')

obj.show_graph()

# %%
# read in the data file  df_raw means no lag
df_raw_std = ts.read_csv('data_boston/boston_data_std.csv')

# add the lag columns
df_raw_std_lag = ts.add_lag_columns(df_raw_std, lag_stub='_lag')
# standardize the data
df_raw_std_lag_std = ts.standardize_df_cols(df_raw_std_lag)

df_raw_std_lag_std
# Out:
#      alcohol_bev       TIB       TST  PANAS_PA  PANAS_NA  worry_scale  \
# 0      -1.008404  2.685616  1.632941 -1.047350  1.651034    -1.431864
# 1       0.780067  0.585698 -0.069185 -1.245249  1.651034    -1.210592
# 2       0.780067  0.885686  0.916256 -1.245249  1.651034    -1.874407
# 3       0.780067  0.285710 -0.606698 -1.443148  2.714592    -1.210592
# 4      -1.008404  0.285710  0.199572 -1.641047  1.651034    -0.989321
# ..           ...       ...       ...       ...       ...          ...
# 635    -0.357411  0.900562  1.284633 -1.011369 -1.403237    -1.356036
# 636    -0.357411  0.436227  0.821988 -0.475641 -1.403237    -1.356036
# 637    -1.151515  0.436227  0.667773  0.060086 -1.089340    -1.356036
# 638    -1.151515  1.364896  1.747278 -0.475641 -1.403237     0.465862
# 639    -0.357411 -0.028107  0.359343 -0.475641 -1.089340    -1.356036
#
#          PHQ9  alcohol_bev_lag   TIB_lag   TST_lag  PANAS_PA_lag  \
# 0   -0.182722         0.777999  1.182483  0.110386     -0.256129
# 1   -0.182722        -1.009803  2.680783  1.633480     -1.047825
# 2   -0.182722         0.777999  0.583163 -0.068802     -1.245749
# 3   -0.182722         0.777999  0.882823  0.916730     -1.245749
# 4   -0.182722         0.777999  0.283503 -0.606364     -1.443673
# ..        ...              ...       ...       ...           ...
# 635  0.037163         1.228561 -2.349103 -1.953670     -0.476045
# 636  1.198061        -0.359054  0.897682  1.285140     -1.011840
# 637  0.037163        -0.359054  0.433855  0.822453     -0.476045
# 638 -1.123735        -1.152862  0.433855  0.668224      0.059750
# 639 -2.284632        -1.152862  1.361508  1.747827     -0.476045
#
#      PANAS_NA_lag  worry_scale_lag  PHQ9_lag
# 0        2.695707        -2.744949 -0.186765
# 1        1.637231        -1.423266 -0.186765
# 2        1.637231        -1.202986 -0.186765
# 3        1.637231        -1.863827 -0.186765
# 4        2.695707        -1.202986 -0.186765
# ..            ...              ...       ...
# 635     -0.465257        -0.440910  0.034017
# 636     -1.402448        -1.347778  0.034017
# 637     -1.402448        -1.347778  1.199654
# 638     -1.090051        -1.347778  0.034017
# 639     -1.402448         0.465958 -1.131619
#
# [640 rows x 14 columns]

# %%
# load prior
prior_lines = ts.read_prior_file('data_boston/boston_prior.txt')
# extract knowledge
knowledge = ts.extract_knowledge(prior_lines)
pprint.pprint(knowledge)

ts.load_knowledge(knowledge)

searchResult = ts.run_model_search(df_raw_std_lag_std, model='gfci',
                                    knowledge=knowledge,
                                                    score={'sem_bic': {'penalty_discount': 1.0}},
                                                    test={'fisher_z': {'alpha': .05}})

edges = list(searchResult['setEdges'])
pprint.pprint(edges)
# Out:
# {'addtemporal': {0: ['alcohol_bev_lag',
#                      'TIB_lag',
#                      'TST_lag',
#                      'PANAS_PA_lag',
#                      'PANAS_NA_lag',
#                      'worry_scale_lag',
#                      'PHQ9_lag'],
#                  1: ['alcohol_bev',
#                      'TIB',
#                      'TST',
#                      'PANAS_PA',
#                      'PANAS_NA',
#                      'worry_scale',
#                      'PHQ9']}}
# ['PHQ9_lag o-> PHQ9',
#  'TIB_lag o-> TST_lag',
#  'worry_scale_lag o-> PANAS_PA',
#  'PANAS_NA_lag o-o PHQ9_lag',
#  'PANAS_PA_lag o-> PANAS_PA',
#  'worry_scale_lag o-> worry_scale',
#  'PHQ9_lag o-o PANAS_PA_lag',
#  'PHQ9 --> PANAS_PA',
#  'PANAS_NA_lag o-> TST_lag',
#  'TIB o-o TST',
#  'PANAS_NA_lag o-> PANAS_NA',
#  'PANAS_NA_lag o-> PHQ9',
#  'PANAS_NA o-> PHQ9']

# %%
edges = list(searchResult['setEdges'])
obj = DgraphFlex()
# add edges to graph object
for edge in edges:
  source,edge_type, target = edge.split(' ')
  obj.add_edge(source,edge_type, target, color='purple')

obj.show_graph()

# %%
# run with our created lag data
searchResult = ts.run_model_search(df_lag_std, model='gfci',
                                                    knowledge=knowledge,
                                                    score={'sem_bic': {'penalty_discount': 1.0}},
                                                    test={'fisher_z': {'alpha': .05}})

edges = list(searchResult['setEdges'])
obj = DgraphFlex()
# add edges to graph object
for edge in edges:
  source,edge_type, target = edge.split(' ')
  obj.add_edge(source,edge_type, target, color='purple')

obj.show_graph()

# %%
import pandas as pd
import numpy as np

# Example DataFrames
data1 = {'col1': [1, 2, 3], 'col2': ['a', 'b', 'c'], 'col3': [True, False, True]}
df1 = pd.DataFrame(data1)

data2 = {'col1': [1, 5, 3], 'col2': ['a', 'x', 'c'], 'col3': [True, True, True]}
df2 = pd.DataFrame(data2)

# Ensure both dataframes have the same columns in the same order for direct comparison
# You might need to reindex or select columns if they are different
# For simplicity, assuming same columns here

diff_mask = df1.ne(df2)

# Apply styling
def highlight_diff(data, diff_mask):
    # Create a dataframe of the same shape with empty strings
    # This is necessary for applying styles based on another dataframe (the mask)
    empty_df = pd.DataFrame('', index=data.index, columns=data.columns)
    # Apply a background color to cells where diff_mask is True
    return empty_df.mask(diff_mask, 'background-color: yellow')

# Apply the styling to one of the dataframes (e.g., df1) based on the diff_mask
# You can then display both styled dataframes side-by-side for comparison
df1_styled = df1.style.apply(highlight_diff, diff_mask=diff_mask, axis=None)
df2_styled = df2.style.apply(highlight_diff, diff_mask=diff_mask, axis=None)

print("Dataframe 1 with differences highlighted:")
display(df1_styled) # Use display() in environments that support it

print("\nDataframe 2 with differences highlighted:")
display(df2_styled) # Use display() in environments that support it
# Out:
# Dataframe 1 with differences highlighted:
# <style type="text/css">
# #T_3fcd9_row1_col0, #T_3fcd9_row1_col1, #T_3fcd9_row1_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_3fcd9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fcd9_level0_col0" class="col_heading level0 col0" >col1</th>
#       <th id="T_3fcd9_level0_col1" class="col_heading level0 col1" >col2</th>
#       <th id="T_3fcd9_level0_col2" class="col_heading level0 col2" >col3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fcd9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fcd9_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3fcd9_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_3fcd9_row0_col2" class="data row0 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_3fcd9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fcd9_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_3fcd9_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_3fcd9_row1_col2" class="data row1 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_3fcd9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3fcd9_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_3fcd9_row2_col1" class="data row2 col1" >c</td>
#       <td id="T_3fcd9_row2_col2" class="data row2 col2" >True</td>
#     </tr>
#   </tbody>
# </table>
# Dataframe 2 with differences highlighted:
# <style type="text/css">
# #T_fd164_row1_col0, #T_fd164_row1_col1, #T_fd164_row1_col2 {
#   background-color: yellow;
# }
# </style>
# <table id="T_fd164" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd164_level0_col0" class="col_heading level0 col0" >col1</th>
#       <th id="T_fd164_level0_col1" class="col_heading level0 col1" >col2</th>
#       <th id="T_fd164_level0_col2" class="col_heading level0 col2" >col3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd164_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd164_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_fd164_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_fd164_row0_col2" class="data row0 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fd164_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd164_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_fd164_row1_col1" class="data row1 col1" >x</td>
#       <td id="T_fd164_row1_col2" class="data row1 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fd164_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd164_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_fd164_row2_col1" class="data row2 col1" >c</td>
#       <td id="T_fd164_row2_col2" class="data row2 col2" >True</td>
#     </tr>
#   </tbody>
# </table>

# %%
print(len(df1))
print(len(df2))
# Out:
# 3
# 3

# %%
# run the sem
